# %% [markdown]
# # Part 4: Quantization

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)
import os
os.environ['PATH'] = '/home/bcilab/Xilinx/Vivado/2019.1/bin:' + os.environ['PATH']

# %% [markdown]
# ## Fetch the jet tagging dataset from Open ML

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %%
DATA_DIR = 'npy'
MODEL_DIR = 'model'

BOARD_NAME = 'ultra96v2'
FPGA_PART = 'xczu3eg-sbva484-1-i' 

CLOCK_PERIOD = 10

# %% [markdown]
# ## Construct a model
# This time we're going to use QKeras layers.
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models.
#
# https://github.com/google/qkeras
#
# It is maintained by Google and we recently added support for QKeras model to hls4ml.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %% [markdown]
# We're using `QDense` layer instead of `Dense`, and `QActivation` instead of `Activation`. We're also specifying `kernel_quantizer = quantized_bits(6,0,0)`. This will use 6-bits (of which 0 are integer) for the weights. We also use the same quantization for the biases, and `quantized_relu(6)` for 6-bit ReLU activations.

# %%
model = Sequential()
model.add(QDense(64, input_shape=(16,), name='fc1',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu1'))
model.add(QDense(32, name='fc2',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu2'))
model.add(QDense(32, name='fc3',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(QActivation(activation=quantized_relu(6), name='relu3'))
model.add(QDense(5, name='output',
                 kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1),
                 kernel_initializer='lecun_uniform', kernel_regularizer=l1(0.0001)))
model.add(Activation(activation='softmax', name='softmax'))

# %% [markdown]
# ## Train sparse
# Let's train with model sparsity again, since QKeras layers are prunable.

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
pruning_params = {"pruning_schedule" : pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)
# Out:
# /home/bcilab/anaconda3/lib/python3.8/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:212: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   mask = self.add_variable(
# /home/bcilab/anaconda3/lib/python3.8/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:219: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   threshold = self.add_variable(
# /home/bcilab/anaconda3/lib/python3.8/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:233: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self.pruning_step = self.add_variable(

# %% [markdown]
# ## Train the model
# We'll use the same settings as the model for part 1: Adam optimizer with categorical crossentropy loss.
# The callbacks will decay the learning rate and save the model into a directory 'model_2'
# The model isn't very complex, so this should just take a few minutes even on the CPU.
# If you've restarted the notebook kernel after training once, set `train = False` to load the trained model rather than training again.

# %%
train = True
if train:
    adam = Adam(lr=0.0001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(stop_patience = 1000,
                              lr_factor = 0.5,
                              lr_patience = 10,
                              lr_epsilon = 0.000001,
                              lr_cooldown = 2,
                              lr_minimum = 0.0000001,
                              outputDir = 'model_3')
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(X_train_val, y_train_val, batch_size=1024,
              epochs=30, validation_split=0.25, shuffle=True,
              callbacks = callbacks.callbacks)
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('model_3/KERAS_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects
    co = {}
    _add_supported_quantized_objects(co)
    model = load_model('model_3/KERAS_check_best_model.h5', custom_objects=co)
# Out:
# /home/bcilab/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/30
# 485/487 [============================>.] - ETA: 0s - loss: 1.3860 - accuracy: 0.4912
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00001: val_loss improved from inf to 1.19395, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00001: val_loss improved from inf to 1.19395, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00001: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00001: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 37s 10ms/step - loss: 1.3854 - accuracy: 0.4916 - val_loss: 1.1940 - val_accuracy: 0.6129 - lr: 1.0000e-04
# Epoch 2/30
# 474/487 [============================>.] - ETA: 0s - loss: 1.1096 - accuracy: 0.6522
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00002: val_loss improved from 1.19395 to 1.04657, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00002: val_loss improved from 1.19395 to 1.04657, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00002: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00002: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 5ms/step - loss: 1.1079 - accuracy: 0.6529 - val_loss: 1.0466 - val_accuracy: 0.6832 - lr: 1.0000e-04
# Epoch 3/30
# 472/487 [============================>.] - ETA: 0s - loss: 1.0019 - accuracy: 0.7013
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00003: val_loss improved from 1.04657 to 0.96335, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00003: val_loss improved from 1.04657 to 0.96335, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00003: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00003: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.0008 - accuracy: 0.7016 - val_loss: 0.9634 - val_accuracy: 0.7124 - lr: 1.0000e-04
# Epoch 4/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.9307 - accuracy: 0.7176
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00004: val_loss improved from 0.96335 to 0.90694, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00004: val_loss improved from 0.96335 to 0.90694, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00004: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00004: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.9307 - accuracy: 0.7175 - val_loss: 0.9069 - val_accuracy: 0.7220 - lr: 1.0000e-04
# Epoch 5/30
# 485/487 [============================>.] - ETA: 0s - loss: 1.1093 - accuracy: 0.6633
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00005: val_loss did not improve from 0.90694
#
# Epoch 00005: val_loss did not improve from 0.90694
#
# Epoch 00005: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00005: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.1092 - accuracy: 0.6634 - val_loss: 1.0581 - val_accuracy: 0.6916 - lr: 1.0000e-04
# Epoch 6/30
# 473/487 [============================>.] - ETA: 0s - loss: 1.0146 - accuracy: 0.7010
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00006: val_loss did not improve from 0.90694
#
# Epoch 00006: val_loss did not improve from 0.90694
#
# Epoch 00006: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00006: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.0138 - accuracy: 0.7012 - val_loss: 0.9864 - val_accuracy: 0.7065 - lr: 1.0000e-04
# Epoch 7/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.9582 - accuracy: 0.7117
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00007: val_loss did not improve from 0.90694
#
# Epoch 00007: val_loss did not improve from 0.90694
#
# Epoch 00007: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00007: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.9580 - accuracy: 0.7117 - val_loss: 0.9407 - val_accuracy: 0.7144 - lr: 1.0000e-04
# Epoch 8/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.9220 - accuracy: 0.7171
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00008: val_loss did not improve from 0.90694
#
# Epoch 00008: val_loss did not improve from 0.90694
#
# Epoch 00008: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00008: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 3ms/step - loss: 0.9220 - accuracy: 0.7172 - val_loss: 0.9104 - val_accuracy: 0.7184 - lr: 1.0000e-04
# Epoch 9/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.8962 - accuracy: 0.7203
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00009: val_loss improved from 0.90694 to 0.88723, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00009: val_loss improved from 0.90694 to 0.88723, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00009: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00009: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8962 - accuracy: 0.7203 - val_loss: 0.8872 - val_accuracy: 0.7216 - lr: 1.0000e-04
# Epoch 10/30
# 480/487 [============================>.] - ETA: 0s - loss: 0.8750 - accuracy: 0.7234
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00010: val_loss improved from 0.88723 to 0.86855, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00010: val_loss improved from 0.88723 to 0.86855, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00010: saving model to model_3/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8748 - accuracy: 0.7234 - val_loss: 0.8686 - val_accuracy: 0.7239 - lr: 1.0000e-04
# Epoch 11/30
# 471/487 [============================>.] - ETA: 0s - loss: 0.8572 - accuracy: 0.7259
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00011: val_loss improved from 0.86855 to 0.85187, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00011: val_loss improved from 0.86855 to 0.85187, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00011: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00011: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8569 - accuracy: 0.7261 - val_loss: 0.8519 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 12/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.8410 - accuracy: 0.7287
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00012: val_loss improved from 0.85187 to 0.83707, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00012: val_loss improved from 0.85187 to 0.83707, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00012: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00012: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8409 - accuracy: 0.7287 - val_loss: 0.8371 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 13/30
# 479/487 [============================>.] - ETA: 0s - loss: 0.8276 - accuracy: 0.7308
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00013: val_loss improved from 0.83707 to 0.82523, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00013: val_loss improved from 0.83707 to 0.82523, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00013: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00013: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8275 - accuracy: 0.7308 - val_loss: 0.8252 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 14/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.8163 - accuracy: 0.7326
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00014: val_loss improved from 0.82523 to 0.81376, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00014: val_loss improved from 0.82523 to 0.81376, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00014: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00014: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8162 - accuracy: 0.7326 - val_loss: 0.8138 - val_accuracy: 0.7329 - lr: 1.0000e-04
# Epoch 15/30
# 483/487 [============================>.] - ETA: 0s - loss: 0.8063 - accuracy: 0.7345
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00015: val_loss improved from 0.81376 to 0.80557, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00015: val_loss improved from 0.81376 to 0.80557, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00015: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00015: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8063 - accuracy: 0.7345 - val_loss: 0.8056 - val_accuracy: 0.7349 - lr: 1.0000e-04
# Epoch 16/30
# 487/487 [==============================] - ETA: 0s - loss: 0.7980 - accuracy: 0.7363
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00016: val_loss improved from 0.80557 to 0.79794, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00016: val_loss improved from 0.80557 to 0.79794, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00016: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00016: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7980 - accuracy: 0.7363 - val_loss: 0.7979 - val_accuracy: 0.7355 - lr: 1.0000e-04
# Epoch 17/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.7910 - accuracy: 0.7378
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00017: val_loss improved from 0.79794 to 0.79140, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00017: val_loss improved from 0.79794 to 0.79140, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00017: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00017: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7910 - accuracy: 0.7379 - val_loss: 0.7914 - val_accuracy: 0.7375 - lr: 1.0000e-04
# Epoch 18/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7844 - accuracy: 0.7391
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00018: val_loss improved from 0.79140 to 0.78658, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00018: val_loss improved from 0.79140 to 0.78658, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00018: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00018: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7846 - accuracy: 0.7390 - val_loss: 0.7866 - val_accuracy: 0.7384 - lr: 1.0000e-04
# Epoch 19/30
# 471/487 [============================>.] - ETA: 0s - loss: 0.7797 - accuracy: 0.7405
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00019: val_loss improved from 0.78658 to 0.78154, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00019: val_loss improved from 0.78658 to 0.78154, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00019: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00019: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7794 - accuracy: 0.7405 - val_loss: 0.7815 - val_accuracy: 0.7402 - lr: 1.0000e-04
# Epoch 20/30
# 470/487 [===========================>..] - ETA: 0s - loss: 0.7749 - accuracy: 0.7417
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00020: val_loss improved from 0.78154 to 0.77723, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00020: val_loss improved from 0.78154 to 0.77723, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00020: saving model to model_3/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7747 - accuracy: 0.7417 - val_loss: 0.7772 - val_accuracy: 0.7410 - lr: 1.0000e-04
# Epoch 21/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.7705 - accuracy: 0.7427
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00021: val_loss improved from 0.77723 to 0.77269, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00021: val_loss improved from 0.77723 to 0.77269, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00021: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00021: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7704 - accuracy: 0.7427 - val_loss: 0.7727 - val_accuracy: 0.7422 - lr: 1.0000e-04
# Epoch 22/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7670 - accuracy: 0.7435
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00022: val_loss improved from 0.77269 to 0.76956, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00022: val_loss improved from 0.77269 to 0.76956, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00022: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00022: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7669 - accuracy: 0.7435 - val_loss: 0.7696 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 23/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7639 - accuracy: 0.7444
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00023: val_loss improved from 0.76956 to 0.76704, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00023: val_loss improved from 0.76956 to 0.76704, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00023: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00023: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7639 - accuracy: 0.7444 - val_loss: 0.7670 - val_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 24/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7611 - accuracy: 0.7453
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00024: val_loss improved from 0.76704 to 0.76464, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00024: val_loss improved from 0.76704 to 0.76464, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00024: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00024: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7612 - accuracy: 0.7452 - val_loss: 0.7646 - val_accuracy: 0.7443 - lr: 1.0000e-04
# Epoch 25/30
# 473/487 [============================>.] - ETA: 0s - loss: 0.7591 - accuracy: 0.7457
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00025: val_loss improved from 0.76464 to 0.76232, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00025: val_loss improved from 0.76464 to 0.76232, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00025: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00025: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7589 - accuracy: 0.7457 - val_loss: 0.7623 - val_accuracy: 0.7448 - lr: 1.0000e-04
# Epoch 26/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.7568 - accuracy: 0.7464
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00026: val_loss improved from 0.76232 to 0.76120, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00026: val_loss improved from 0.76232 to 0.76120, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00026: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00026: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7569 - accuracy: 0.7464 - val_loss: 0.7612 - val_accuracy: 0.7456 - lr: 1.0000e-04
# Epoch 27/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.7550 - accuracy: 0.7467
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00027: val_loss improved from 0.76120 to 0.75915, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00027: val_loss improved from 0.76120 to 0.75915, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00027: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00027: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7550 - accuracy: 0.7467 - val_loss: 0.7591 - val_accuracy: 0.7459 - lr: 1.0000e-04
# Epoch 28/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7535 - accuracy: 0.7472
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00028: val_loss improved from 0.75915 to 0.75755, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00028: val_loss improved from 0.75915 to 0.75755, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00028: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00028: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7534 - accuracy: 0.7472 - val_loss: 0.7576 - val_accuracy: 0.7466 - lr: 1.0000e-04
# Epoch 29/30
# 487/487 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.7478
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00029: val_loss improved from 0.75755 to 0.75591, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00029: val_loss improved from 0.75755 to 0.75591, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00029: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00029: saving model to model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7520 - accuracy: 0.7478 - val_loss: 0.7559 - val_accuracy: 0.7467 - lr: 1.0000e-04
# Epoch 30/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.7504 - accuracy: 0.7481
# ***callbacks***
# saving losses to model_3/losses.log
#
# Epoch 00030: val_loss improved from 0.75591 to 0.75547, saving model to model_3/KERAS_check_best_model.h5
#
# Epoch 00030: val_loss improved from 0.75591 to 0.75547, saving model to model_3/KERAS_check_best_model_weights.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_last.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_last_weights.h5
#
# Epoch 00030: saving model to model_3/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7503 - accuracy: 0.7481 - val_loss: 0.7555 - val_accuracy: 0.7472 - lr: 1.0000e-04
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Check performance
# How does this model which was trained using 6-bits, and 75% sparsity model compare against the original model? Let's report the accuracy and make a ROC curve. The quantized, pruned model is shown with solid lines, the unpruned model from part 1 is shown with dashed lines.
#
#
# We should also check that hls4ml can respect the choice to use 6-bits throughout the model, and match the accuracy. We'll generate a configuration from this Quantized model, and plot its performance as the dotted line.
# The generated configuration is printed out. You'll notice that it uses 7 bits for the type, but we specified 6!? That's just because QKeras doesn't count the sign-bit when we specify the number of bits, so the type that actually gets used needs 1 more.
#
# We also use the `OutputRoundingSaturationMode` optimizer pass of `hls4ml` to set the Activation layers to round, rather than truncate, the cast. This is important for getting good model accuracy when using small bit precision activations. And we'll set a different data type for the tables used in the Softmax, just for a bit of extra performance.
#
#
# **Make sure you've trained the model from part 1**

# %%
import hls4ml
import plotting
hls4ml.model.optimizer.OutputRoundingSaturationMode.layers = ['Activation']
hls4ml.model.optimizer.OutputRoundingSaturationMode.rounding_mode = 'AP_RND'
hls4ml.model.optimizer.OutputRoundingSaturationMode.saturation_mode = 'AP_SAT'

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
config['LayerName']['softmax']['exp_table_t'] = 'ap_fixed<18,8>'
config['LayerName']['softmax']['inv_table_t'] = 'ap_fixed<18,4>'
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(model=model,
                                     clock_period=CLOCK_PERIOD,
                                     backend='VivadoAccelerator',
                                     board=BOARD_NAME,
                                     part=FPGA_PART,
                                     io_type='io_stream',
                                     interface='axi_stream',
                                     driver='c',
                                     hls_config=config,
                                     output_dir='model_3/hls4ml_prj')
hls_model.compile()

y_qkeras = model.predict(np.ascontiguousarray(X_test))
y_hls = hls_model.predict(np.ascontiguousarray(X_test))
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: Input
# Layer name: fc1, layer type: QDense
# Layer name: relu1, layer type: QActivation
# Layer name: fc2, layer type: QDense
# Layer name: relu2, layer type: QActivation
# Layer name: fc3, layer type: QDense
# Layer name: relu3, layer type: QActivation
# Layer name: output, layer type: QDense
# Layer name: softmax, layer type: Activation
# -----------------------------------
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
# LayerName
#   fc1_input
#     Precision
#       result:        ap_fixed<16,6>
#   fc1
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu1
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc2
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu2
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc3
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   relu3
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   output
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   softmax
#     Precision:       ap_fixed<16,6>
#     ReuseFactor:     1
#     table_size:      1024
#     exp_table_t:     ap_fixed<18,8>
#     inv_table_t:     ap_fixed<18,4>
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 16]], output shape: [None, 64]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 64]], output shape: [None, 32]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: relu3, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: output, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 5]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 5]], output shape: [None, 5]
# Creating HLS model
# shape: [64]
# dims: ['N_LAYER_3']
# shape: [64]
# dims: ['N_LAYER_4']
# shape: [32]
# dims: ['N_LAYER_6']
# shape: [32]
# dims: ['N_LAYER_7']
# shape: [32]
# dims: ['N_LAYER_9']
# shape: [32]
# dims: ['N_LAYER_10']
# shape: [5]
# dims: ['N_LAYER_12']
# WARNING: You set a XilinxPart that does not correspond to the Board you specified. The correct XilinxPart is now set.
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %%
# %matplotlib inline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

model_ref = load_model('model_1/KERAS_check_best_model.h5')
y_ref = model_ref.predict(X_test)

print("Accuracy baseline:  {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned, quantized: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))))
print("Accuracy hls4ml: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None) # reset the colors
_ = plotting.makeRoc(y_test, y_qkeras, classes, linestyle='--')
plt.gca().set_prop_cycle(None) # reset the colors
_ = plotting.makeRoc(y_test, y_hls, classes, linestyle=':')

from matplotlib.lines import Line2D
lines = [Line2D([0], [0], ls='-'),
         Line2D([0], [0], ls='--'),
         Line2D([0], [0], ls=':')]
from matplotlib.legend import Legend
leg = Legend(ax, lines, labels=['baseline', 'pruned, quantized', 'hls4ml'],
            loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# Accuracy baseline:  0.7502530120481927
# Accuracy pruned, quantized: 0.7458493975903614
# Accuracy hls4ml: 0.20164457831325303

# %% [markdown]
# # Synthesize
# Now let's synthesize this quantized, pruned model.
#
# **The synthesis will take a while**
#
# While the C-Synthesis is running, we can monitor the progress looking at the log file by opening a terminal from the notebook home, and executing:
#
# `tail -f model_3/hls4ml_prj/vivado_hls.log`

# %%
hls_model.build(csim=False, synth=True, export=True)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2019.1 (64-bit)
#   **** SW Build 2552052 on Fri May 24 14:47:09 MDT 2019
#   **** IP Build 2548770 on Fri May 24 18:01:18 MDT 2019
#     ** Copyright 1986-2019 Xilinx, Inc. All Rights Reserved.
#
# source /home/bcilab/Xilinx/Vivado/2019.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: Applying HLS Y2K22 patch v1.2 for IP revision
# INFO: [HLS 200-10] Running '/home/bcilab/Xilinx/Vivado/2019.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'bcilab' on host 'bcilab-rrid411' (Linux_x86_64 version 4.15.0-188-generic) on Wed Jul 13 10:12:38 IST 2022
# INFO: [HLS 200-10] On os Ubuntu 18.04.6 LTS
# INFO: [HLS 200-10] In directory '/home/bcilab/NN_fpga/hls4ml-tutorial/model_3/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Opening project '/home/bcilab/NN_fpga/hls4ml-tutorial/model_3/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject_axi.cpp' to the project
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Opening solution '/home/bcilab/NN_fpga/hls4ml-tutorial/model_3/hls4ml_prj/myproject_prj/solution1'.
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 10ns.
# INFO: [HLS 200-10] Setting target device to 'xczu3eg-sbva484-1-e'
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 60.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 60.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/nnet_utils/nnet_dense_latency.h:64:9
# WARNING: [HLS 214-104] Only for-loops and functions support the dataflow: firmware/nnet_utils/nnet_dense_latency.h:76:9
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/myproject.cpp:35:2
# WARNING: [HLS 200-471] Dataflow form checks found 3 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject_axi.cpp' ...
# WARNING: [HLS 214-111] Streams will behave like static variables inside a dataflow region: firmware/myproject_axi.cpp:17:26
# WARNING: [HLS 200-471] Dataflow form checks found 1 issue(s) in file firmware/myproject_axi.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:28 ; elapsed = 00:00:33 . Memory (MB): peak = 896.254 ; gain = 194.969 ; free physical = 1851 ; free virtual = 13478
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:28 ; elapsed = 00:00:33 . Memory (MB): peak = 896.254 ; gain = 194.969 ; free physical = 1851 ; free virtual = 13478
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:27).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>' (firmware/nnet_utils/nnet_dense_stream.h:48).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator=' (firmware/nnet_utils/nnet_types.h:34).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:57).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:96).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_stream.h:22).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>' (firmware/nnet_utils/nnet_dense_stream.h:48).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>' (firmware/nnet_utils/nnet_dense_stream.h:62).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[].1' into 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator=' (firmware/nnet_utils/nnet_types.h:34).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:57).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:57).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:57).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:96).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:96).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:96).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_stream.h:22).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>' (firmware/nnet_utils/nnet_dense_stream.h:48).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' (firmware/nnet_utils/nnet_dense_stream.h:62).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' (firmware/nnet_utils/nnet_dense_stream.h:48).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>' (firmware/nnet_utils/nnet_dense_stream.h:62).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[].1' into 'nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator=' (firmware/nnet_utils/nnet_types.h:34).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_stream.h:22).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_latency<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_stream.h:22).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:39).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:171).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:155).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>' (firmware/nnet_utils/nnet_dense_stream.h:62).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[].1' into 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator=' (firmware/nnet_utils/nnet_types.h:34).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:31 ; elapsed = 00:00:37 . Memory (MB): peak = 902.039 ; gain = 200.754 ; free physical = 1748 ; free virtual = 13375
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::mantissa' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:15) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::expv' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:18) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::__signbit' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:59) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' into 'generic_cast_IEEE754<int, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:117) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, double>' into '__hls_fptosi_double_i32' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/src/lib_floatconversion.cpp:55) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:53) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::softmax_idx_from_real_val<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config13>' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:155) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:162) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::softmax_idx_from_real_val<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config13>' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:164) automatically.
# WARNING: [SYNCHK 200-23] firmware/myproject_axi.cpp:39: variable-indexed range selection may cause suboptimal QoR.
# INFO: [SYNCHK 200-10] 0 error(s), 1 warning(s).
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:33 ; elapsed = 00:00:38 . Memory (MB): peak = 964.457 ; gain = 263.172 ; free physical = 1700 ; free virtual = 13327
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'res.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'res.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'data_stream.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:32:1) on argument 'fc1_input.V.data.V' (firmware/myproject.cpp:25). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:32:96) on argument 'layer13_out.V.data.V' (firmware/myproject.cpp:26). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'out.data' (firmware/myproject_axi.cpp:5).
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'in.data' (firmware/myproject_axi.cpp:4).
# INFO: [XFORM 203-1101] Packing variable 'out_pack.data.V' (firmware/nnet_utils/nnet_activation_stream.h:166) into a 80-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:58) into a 192-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:58) into a 192-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:58) into a 80-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:58) into a 384-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'ctype.data.V' (firmware/myproject_axi.cpp:24) into a 256-bit variable.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:32:59).
# INFO: [XFORM 203-502] Unrolling small iteration loop 'Loop-1' (firmware/myproject_axi.cpp:23) in function 'myproject_axi' automatically.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:20:55).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:20:55).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:20:55).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:20:55).
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:32) in function 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'SoftmaxExpPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:153) in function 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'SoftmaxInvPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:168) in function 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:32) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:46) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:60) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:32) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:46) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:60) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:32) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:46) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:60) in function 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:32) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:46) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:60) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/myproject_axi.cpp:23) in function 'myproject_axi' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'Loop-2' (firmware/nnet_utils/nnet_types.h:32) in function 'myproject_axi' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:85) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:90) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:101) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:109) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:113) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:120) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:85) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:90) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:101) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:109) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:113) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:120) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:85) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:90) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:101) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:109) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:113) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:120) in function 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 32.
# INFO: [HLS 200-489] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:85) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:90) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:101) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:109) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:113) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:120) in function 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64.
# INFO: [XFORM 203-102] Partitioning array 'tmp.data.V.9' automatically.
# INFO: [XFORM 203-102] Partitioning array 'tmp.data.V.3' automatically.
# INFO: [XFORM 203-102] Partitioning array 'tmp.data.V.5' automatically.
# INFO: [XFORM 203-102] Partitioning array 'tmp.data.V.7' automatically.
# INFO: [XFORM 203-102] Partitioning array 'tmp.data.V.1' automatically.
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer12_out.V.data.V' (firmware/myproject.cpp:72) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'out_local.V.data.V' (firmware/myproject_axi.cpp:18) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer4_out.V.data.V' (firmware/myproject.cpp:60) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer7_out.V.data.V' (firmware/myproject.cpp:64) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer10_out.V.data.V' (firmware/myproject.cpp:68) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'in_local.V.data.V' .
# INFO: [XFORM 203-101] Partitioning array 'exp_res.V' (firmware/nnet_utils/nnet_activation_stream.h:146) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.2' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.4' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.6' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.8' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.10' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.12' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b11.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:39) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:40) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b8.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:39) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:40) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b5.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:39) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:40) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b2.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'mult.V' (firmware/nnet_utils/nnet_dense_latency.h:39) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_latency.h:40) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer12_out.V.data.V' (firmware/myproject.cpp:72) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'out_local.V.data.V' (firmware/myproject_axi.cpp:18) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer4_out.V.data.V' (firmware/myproject.cpp:60) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer7_out.V.data.V' (firmware/myproject.cpp:64) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer10_out.V.data.V' (firmware/myproject.cpp:68) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'in_local.V.data.V' in dimension 1 completely.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::mantissa' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:15) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::expv' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:18) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::__signbit' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:59) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' into 'generic_cast_IEEE754<int, double>' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:117) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, double>' into '__hls_fptosi_double_i32' (/wrk/2019.1/continuous/2019_05_24_2552052/src/products/hls/hls_lib/hlsmath/src/lib_floatconversion.cpp:55) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:56->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' into 'nnet::dense_wrapper<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config12>' (firmware/nnet_utils/nnet_dense_latency.h:125->firmware/nnet_utils/nnet_dense_stream.h:22) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:53) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' (firmware/nnet_utils/nnet_common.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::softmax_idx_from_real_val<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config13>' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:155) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:162) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::softmax_idx_from_real_val<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config13>' into 'nnet::softmax_latency<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>' (firmware/nnet_utils/nnet_activation_stream.h:164) automatically.
# INFO: [XFORM 203-721] Change variable 'tmp.data.V' to FIFO automatically.
# INFO: [XFORM 203-721] Changing loop 'Loop_2_proc' (firmware/myproject_axi.cpp:37) to a process function for dataflow in function 'myproject_axi'.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject', detected/extracted 6 process function(s):
# 	 'myproject_Block__proc'
# 	 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>'
# 	 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config7>'
# 	 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>'
# 	 'nnet::dense<nnet::array<ap_ufixed<6, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config12>'
# 	 'nnet::softmax<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config13>'.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject_axi', detected/extracted 4 process function(s):
# 	 'Block_codeRepl344_proc260'
# 	 'myproject'
# 	 'Block_myproject_axi_.exit346_proc261'
# 	 'Loop_2_proc'.
# ...
# INFO: [HLS 200-111]  Elapsed time: 0.02 seconds; current allocated memory: 518.993 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'Loop_2_proc'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.07 seconds; current allocated memory: 519.234 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.08 seconds; current allocated memory: 519.537 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'myproject_axi'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.1 seconds; current allocated memory: 519.724 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 1.61 seconds; current allocated memory: 521.503 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Block_codeRepl344_proc260'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Generating core module 'myproject_axi_fpext_32ns_64_2_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Block_codeRepl344_proc260'.
# INFO: [HLS 200-111]  Elapsed time: 1.74 seconds; current allocated memory: 523.832 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_fixed_ap_ufixed_6_0_5_3_0_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_fixed_ap_ufixed_6_0_5_3_0_config4_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.69 seconds; current allocated memory: 540.717 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_array_ap_ufixed_6_0_5_3_0_64u_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_array_ap_ufixed_6_0_5_3_0_64u_config4_s'.
# INFO: [HLS 200-111]  Elapsed time: 2.11 seconds; current allocated memory: 561.864 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_ufixed_ap_ufixed_6_0_5_3_0_config7_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_ufixed_ap_ufixed_6_0_5_3_0_config7_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.95 seconds; current allocated memory: 578.291 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_array_ap_ufixed_6_0_5_3_0_32u_config7_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_array_ap_ufixed_6_0_5_3_0_32u_config7_s'.
# INFO: [HLS 200-111]  Elapsed time: 4.6 seconds; current allocated memory: 619.602 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_ufixed_ap_ufixed_6_0_5_3_0_config10_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_ufixed_ap_ufixed_6_0_5_3_0_config10_s'.
# INFO: [HLS 200-111]  Elapsed time: 1.46 seconds; current allocated memory: 630.125 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_array_ap_ufixed_6_0_5_3_0_32u_config10_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_array_ap_ufixed_6_0_5_3_0_32u_config10_s'.
# INFO: [HLS 200-111]  Elapsed time: 2.93 seconds; current allocated memory: 651.422 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_ufixed_ap_fixed_16_6_5_3_0_config12_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_ufixed_ap_fixed_16_6_5_3_0_config12_s'.
# INFO: [HLS 200-111]  Elapsed time: 1.25 seconds; current allocated memory: 654.786 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_array_ap_fixed_16_6_5_3_0_5u_config12_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_array_ap_fixed_16_6_5_3_0_5u_config12_s'.
# INFO: [HLS 200-111]  Elapsed time: 1.25 seconds; current allocated memory: 660.810 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'softmax_latency_array_array_softmax_config13_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SYN 201-210] Renamed object name 'softmax_latency_array_array_softmax_config13_s_invert_table8' to 'softmax_latency_array_array_softmax_config13_s_invert_tabbkb' due to the length limit 60
# INFO: [RTGEN 206-100] Finished creating RTL model for 'softmax_latency_array_array_softmax_config13_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.95 seconds; current allocated memory: 662.363 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'softmax_array_array_ap_fixed_5u_softmax_config13_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'softmax_array_array_ap_fixed_5u_softmax_config13_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.88 seconds; current allocated memory: 663.738 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SYN 201-210] Renamed object name 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_config7_U0' to 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_conficud' due to the length limit 60
# INFO: [SYN 201-210] Renamed object name 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_config10_U0' to 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_confidEe' due to the length limit 60
# INFO: [SYN 201-210] Renamed object name 'start_for_dense_array_array_ap_fixed_16_6_5_3_0_5u_config12_U0' to 'start_for_dense_array_array_ap_fixed_16_6_5_3_0_5u_configeOg' due to the length limit 60
# INFO: [SYN 201-210] Renamed object name 'start_for_softmax_array_array_ap_fixed_5u_softmax_config13_U0' to 'start_for_softmax_array_array_ap_fixed_5u_softmax_config1fYi' due to the length limit 60
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [HLS 200-111]  Elapsed time: 0.99 seconds; current allocated memory: 669.735 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Block_myproject_axi_exit346_proc261'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Block_myproject_axi_exit346_proc261'.
# INFO: [HLS 200-111]  Elapsed time: 3.41 seconds; current allocated memory: 675.216 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Loop_2_proc'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Loop_2_proc'.
# INFO: [HLS 200-111]  Elapsed time: 0.93 seconds; current allocated memory: 676.158 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject_axi'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject_axi/in_data' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject_axi/in_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject_axi/out_data' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject_axi/out_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject_axi' to 'ap_ctrl_none'.
# INFO: [HLS 200-633] Setting ap_ctrl_none interface for myproject_axi
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject_axi'.
# INFO: [HLS 200-111]  Elapsed time: 1.08 seconds; current allocated memory: 678.453 MB.
# INFO: [RTMG 210-279] Implementing memory 'softmax_latency_array_array_softmax_config13_s_exp_table7_rom' using block ROMs.
# INFO: [RTMG 210-279] Implementing memory 'softmax_latency_array_array_softmax_config13_s_invert_tabbkb_rom' using auto ROMs.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_conficud_U(start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_conficud)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_confidEe_U(start_for_dense_array_array_ap_ufixed_6_0_5_3_0_32u_confidEe)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_array_ap_fixed_16_6_5_3_0_5u_configeOg_U(start_for_dense_array_array_ap_fixed_16_6_5_3_0_5u_configeOg)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_softmax_array_array_ap_fixed_5u_softmax_config1fYi_U(start_for_softmax_array_array_ap_fixed_5u_softmax_config1fYi)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_0_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_1_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_2_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_3_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_4_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_5_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_6_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_7_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_8_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_9_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_10_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_11_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_12_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_13_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_14_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'in_local_V_data_V_15_U(fifo_w16_d16_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'is_last_1_i_0_loc_c_U(fifo_w1_d4_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'out_local_V_data_0_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'out_local_V_data_1_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'out_local_V_data_2_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'out_local_V_data_3_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'out_local_V_data_4_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'tmp_data_V_U(fifo_w16_d5_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_myproject_U0_U(start_for_myproject_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_Loop_2_proc_U0_U(start_for_Loop_2_proc_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_Block_myproject_axi_exit346_proc261_U0_U(start_for_Block_myproject_axi_exit346_proc261_U0)' using Shift Registers.
# INFO: [HLS 200-111] Finished generating all RTL models Time (s): cpu = 00:02:49 ; elapsed = 00:03:58 . Memory (MB): peak = 5144.281 ; gain = 4442.996 ; free physical = 1392 ; free virtual = 10978
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject_axi.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject_axi.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h3m56s *****
# ***** EXPORT IP *****
# INFO: [IMPL 213-8] Exporting RTL as a Vivado IP.
#
# ****** Vivado v2019.1 (64-bit)
#   **** SW Build 2552052 on Fri May 24 14:47:09 MDT 2019
#   **** IP Build 2548770 on Fri May 24 18:01:18 MDT 2019
#     ** Copyright 1986-2019 Xilinx, Inc. All Rights Reserved.
#
# source run_ippack.tcl -notrace
# INFO: [IP_Flow 19-234] Refreshing IP repositories
# INFO: [IP_Flow 19-1704] No user IP repositories specified
# INFO: [IP_Flow 19-2313] Loaded Vivado IP repository '/home/bcilab/Xilinx/Vivado/2019.1/data/ip'.
# WARNING: [IP_Flow 19-4832] The IP name 'myproject_axi_ap_fpext_0_no_dsp_32' you have specified is long. The Windows operating system has path length limitations. It is recommended you use shorter names to reduce the likelihood of issues.
# create_ip: Time (s): cpu = 00:00:03 ; elapsed = 00:00:09 . Memory (MB): peak = 1430.621 ; gain = 63.980 ; free physical = 417 ; free virtual = 10860
# INFO: [IP_Flow 19-1686] Generating 'Synthesis' target for IP 'myproject_axi_ap_fpext_0_no_dsp_32'...
# INFO: [IP_Flow 19-1686] Generating 'Simulation' target for IP 'myproject_axi_ap_fpext_0_no_dsp_32'...
# INFO: [IP_Flow 19-234] Refreshing IP repositories
# INFO: [IP_Flow 19-1704] No user IP repositories specified
# INFO: [IP_Flow 19-2313] Loaded Vivado IP repository '/home/bcilab/Xilinx/Vivado/2019.1/data/ip'.
# INFO: [Common 17-206] Exiting Vivado at Wed Jul 13 10:17:47 2022...
# ***** EXPORT IP COMPLETED IN 0h1m12s *****
# INFO: [HLS 200-112] Total elapsed time: 310.71 seconds; peak allocated memory: 678.453 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Wed Jul 13 10:17:48 2022...
# {'EstimatedClockPeriod': '8.716',
#  'BestLatency': '49',
#  'WorstLatency': '49',
#  'IntervalMin': '50',
#  'IntervalMax': '50',
#  'BRAM_18K': '4',
#  'DSP48E': '21',
#  'FF': '2349',
#  'LUT': '46027',
#  'URAM': '0',
#  'AvailableBRAM_18K': '432',
#  'AvailableDSP48E': '360',
#  'AvailableFF': '141120',
#  'AvailableLUT': '70560',
#  'AvailableURAM': '0'}

# %% [markdown]
# ## Check the reports
# Print out the reports generated by Vivado HLS. Pay attention to the Utilization Estimates' section in particular this time.

# %%
hls4ml.report.read_vivado_report('model_3/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_3/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject_axi'
# ================================================================
# * Date:           Wed Jul 13 10:16:29 2022
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynquplus
# * Target device:  xczu3eg-sbva484-1-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |  10.00|     8.716|        1.25|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-----+-----+-----+-----+----------+
#     |  Latency  |  Interval | Pipeline |
#     | min | max | min | max |   Type   |
#     +-----+-----+-----+-----+----------+
#     |   49|   49|   50|   50| dataflow |
#     +-----+-----+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |                                        |                                     |  Latency  |  Interval | Pipeline |
#         |                Instance                |                Module               | min | max | min | max |   Type   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |myproject_U0                            |myproject                            |   10|   10|    3|    3| dataflow |
#         |Block_codeRepl344_proc260_U0            |Block_codeRepl344_proc260            |   49|   49|   49|   49|   none   |
#         |Loop_2_proc_U0                          |Loop_2_proc                          |   16|   16|   16|   16|   none   |
#         |Block_myproject_axi_exit346_proc261_U0  |Block_myproject_axi_exit346_proc261  |    4|    4|    4|    4|   none   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|      2|    -|
# |FIFO             |        0|      -|     147|    696|    -|
# |Instance         |        4|     21|    2202|  45329|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|      -|    -|
# |Register         |        -|      -|       -|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |        4|     21|    2349|  46027|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      432|    360|  141120|  70560|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |    ~0   |      5|       1|     65|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |                Instance                |                Module               | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |Block_codeRepl344_proc260_U0            |Block_codeRepl344_proc260            |        0|      0|   500|   5435|    0|
#     |Block_myproject_axi_exit346_proc261_U0  |Block_myproject_axi_exit346_proc261  |        0|      0|    70|    133|    0|
#     |Loop_2_proc_U0                          |Loop_2_proc                          |        0|      0|   187|   1057|    0|
#     |myproject_U0                            |myproject                            |        4|     21|  1445|  38704|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |Total                                   |                                     |        4|     21|  2202|  45329|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# Print the report for the model trained in part 1. Now, compared to the model from part 1, this model has been trained with low-precision quantization, and 75% pruning. You should be able to see that we have saved a lot of resource compared to where we started in part 1. At the same time, referring to the ROC curve above, the model performance is pretty much identical even with this drastic compression!
#
# **Note you need to have trained and synthesized the model from part 1**

# %%
hls4ml.report.read_vivado_report('model_1/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_1/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject_axi'
# ================================================================
# * Date:           Mon Jul 11 11:07:01 2022
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynquplus
# * Target device:  xczu3eg-sbva484-1-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |  10.00|     8.716|        1.25|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-----+-----+-----+-----+----------+
#     |  Latency  |  Interval | Pipeline |
#     | min | max | min | max |   Type   |
#     +-----+-----+-----+-----+----------+
#     |   75|   76|   66|   67| dataflow |
#     +-----+-----+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |                                        |                                     |  Latency  |  Interval | Pipeline |
#         |                Instance                |                Module               | min | max | min | max |   Type   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |myproject_U0                            |myproject                            |   73|   74|   66|   67| dataflow |
#         |Block_codeRepl342_proc266_U0            |Block_codeRepl342_proc266            |   49|   49|   49|   49|   none   |
#         |Loop_2_proc_U0                          |Loop_2_proc                          |   16|   16|   16|   16|   none   |
#         |Block_myproject_axi_exit344_proc267_U0  |Block_myproject_axi_exit344_proc267  |    4|    4|    4|    4|   none   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|      2|    -|
# |FIFO             |        0|      -|     147|    696|    -|
# |Instance         |       69|    149|   14234|  43087|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|      -|    -|
# |Register         |        -|      -|       -|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |       69|    149|   14381|  43785|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      432|    360|  141120|  70560|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |       15|     41|      10|     62|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +----------------------------------------+-------------------------------------+---------+-------+-------+-------+-----+
#     |                Instance                |                Module               | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +----------------------------------------+-------------------------------------+---------+-------+-------+-------+-----+
#     |Block_codeRepl342_proc266_U0            |Block_codeRepl342_proc266            |        0|      0|    500|   5435|    0|
#     |Block_myproject_axi_exit344_proc267_U0  |Block_myproject_axi_exit344_proc267  |        0|      0|     70|    133|    0|
#     |Loop_2_proc_U0                          |Loop_2_proc                          |        0|      0|    187|   1057|    0|
#     |myproject_U0                            |myproject                            |       69|    149|  13477|  36462|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                   |                                     |       69|    149|  14234|  43087|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# Print the report for the model trained in part 3. Both these models were trained with 75% sparsity, but the new model uses 6-bit precision as well. You can see how Vivado HLS has moved multiplication operations from DSPs into LUTs, reducing the "critical" resource usage.
#
# **Note you need to have trained and synthesized the model from part 3**

# %%
hls4ml.report.read_vivado_report('model_2/hls4ml_prj')
# Out:
# Found 1 solution(s) in model_2/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject_axi'
# ================================================================
# * Date:           Wed Jul 13 09:58:46 2022
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynquplus
# * Target device:  xczu3eg-sbva484-1-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |  10.00|     8.716|        1.25|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-----+-----+-----+-----+----------+
#     |  Latency  |  Interval | Pipeline |
#     | min | max | min | max |   Type   |
#     +-----+-----+-----+-----+----------+
#     |   49|   49|   50|   50| dataflow |
#     +-----+-----+-----+-----+----------+
#
#     + Detail:
#         * Instance:
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |                                        |                                     |  Latency  |  Interval | Pipeline |
#         |                Instance                |                Module               | min | max | min | max |   Type   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#         |myproject_U0                            |myproject                            |   11|   11|    3|    3| dataflow |
#         |Block_codeRepl344_proc260_U0            |Block_codeRepl344_proc260            |   49|   49|   49|   49|   none   |
#         |Loop_2_proc_U0                          |Loop_2_proc                          |   16|   16|   16|   16|   none   |
#         |Block_myproject_axi_exit346_proc261_U0  |Block_myproject_axi_exit346_proc261  |    4|    4|    4|    4|   none   |
#         +----------------------------------------+-------------------------------------+-----+-----+-----+-----+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|      2|    -|
# |FIFO             |        0|      -|     147|    696|    -|
# |Instance         |        4|    914|    3793|  43907|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|      -|    -|
# |Register         |        -|      -|       -|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |        4|    914|    3940|  44605|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      432|    360|  141120|  70560|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |    ~0   |    253|       2|     63|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |                Instance                |                Module               | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |Block_codeRepl344_proc260_U0            |Block_codeRepl344_proc260            |        0|      0|   500|   5435|    0|
#     |Block_myproject_axi_exit346_proc261_U0  |Block_myproject_axi_exit346_proc261  |        0|      0|    70|    133|    0|
#     |Loop_2_proc_U0                          |Loop_2_proc                          |        0|      0|   187|   1057|    0|
#     |myproject_U0                            |myproject                            |        4|    914|  3036|  37282|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#     |Total                                   |                                     |        4|    914|  3793|  43907|    0|
#     +----------------------------------------+-------------------------------------+---------+-------+------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# ## NB
# Note as well that the Vivado HLS resource estimates tend to _overestimate_ LUTs, while generally estimating the DSPs correctly. Running the subsequent stages of FPGA compilation reveals the more realistic resource usage, You can run the next step, 'logic synthesis' with `hls_model.build(synth=True, vsynth=True)`, but we skipped it in this tutorial in the interest of time.
